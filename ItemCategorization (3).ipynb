# %% [markdown]
# #### Imports

# %%
pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in /Users/anu/Library/Python/3.9/lib/python/site-packages (1.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from openai) (2.6.3)
# Requirement already satisfied: sniffio in /Users/anu/Library/Python/3.9/lib/python/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /Users/anu/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/anu/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4 langchain transformers torch sentence-transformers nltk spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bs4 in /Users/anu/Library/Python/3.9/lib/python/site-packages (0.0.2)
# Requirement already satisfied: langchain in /Users/anu/Library/Python/3.9/lib/python/site-packages (0.1.9)
# Requirement already satisfied: transformers in /Users/anu/Library/Python/3.9/lib/python/site-packages (4.38.2)
# Requirement already satisfied: torch in /Users/anu/Library/Python/3.9/lib/python/site-packages (2.2.1)
# Requirement already satisfied: sentence-transformers in /Users/anu/Library/Python/3.9/lib/python/site-packages (2.4.0)
# Requirement already satisfied: nltk in /Users/anu/Library/Python/3.9/lib/python/site-packages (3.8.1)
# Requirement already satisfied: spacy in /Users/anu/Library/Python/3.9/lib/python/site-packages (3.7.4)
# Requirement already satisfied: beautifulsoup4 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from bs4) (4.12.3)
# Requirement already satisfied: PyYAML>=5.3 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.21 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (0.0.24)
# Requirement already satisfied: langchain-core<0.2,>=0.1.26 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (0.1.27)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (0.1.10)
# Requirement already satisfied: numpy<2,>=1 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (1.26.3)
# Requirement already satisfied: pydantic<3,>=1 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (2.6.3)
# Requirement already satisfied: requests<3,>=2 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: filelock in /Users/anu/Library/Python/3.9/lib/python/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from transformers) (0.21.2)
# Requirement already satisfied: packaging>=20.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from transformers) (23.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /Users/anu/Library/Python/3.9/lib/python/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /Users/anu/Library/Python/3.9/lib/python/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /Users/anu/Library/Python/3.9/lib/python/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: scikit-learn in /Users/anu/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in /Users/anu/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: Pillow in /Users/anu/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: click in /Users/anu/Library/Python/3.9/lib/python/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Users/anu/Library/Python/3.9/lib/python/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from spacy) (58.0.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2,>=0.1.26->langchain) (4.3.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from langsmith<0.2.0,>=0.1.0->langchain) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.26->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.26->langchain) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from tqdm import tqdm
import os
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Data collection

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

def run_GPT4(document,model='gpt-3.5-turbo-0125'):
    try:
        prmpt = """
## Dish Information Generation Prompt

Generate a comprehensive dataset for a dish, including detailed input features and output classifications. Input features should encompass the main ingredients, nutritional content, region of popularity, a brief description, spice level, cooking method, preparation time, and allergen presence. Based on these inputs, output classifications will include the dish's cuisine type, meal type, dietary preference, and health considerations.

### Input Features to Generate
- **List of Main Ingredients**: Specify main components in string format.
- **Nutritional Value per Serving**: Provide values for calories, saturated fat (% daily value), sugar (g), protein (g), and glycemic index.
- **Region**: Name the region where the dish is popular.
- **Description**: Give a 100-word description.
- **Spice Level**: Rate from 0 to 10.
- **Cooking Method**: Describe the primary cooking method.
- **Preparation Time**: List in minutes.
- **Contains Allergens**: Indicate with true/false.

### Output Classifications
- **Cuisine Type**: The culinary tradition of the dish.
- **Meal Type**: Suitable times for consumption, allowing multiple values.
- **Dietary Preference**: Categorize as Veg, Non-Veg, or Vegan.
- **Protein Rich**: Indicate with true/false if high in protein.
- **Pregnancy Safe**: Mark with true/false based on safety for pregnancy.
- **Diabetic Friendly**: Show with true/false if suitable for diabetics.

### Expected JSON Format
```json
{
  "InputCols": {
    "List of Main Ingredients": "String",
    "Nutritional Value per Serving": {
      "Calories": "Integer",
      "Saturated Fat in daily %": "Integer",
      "Sugar in g": "Integer",
      "Protein in g": "Integer",
      "Glycemic Index": "Integer"
    },
    "Region where Dish is Popular": "String",
    "Description": "String",
    "Spice Level": "Integer",
    "Cooking Method": "String",
    "Preparation Time": "Integer",
    "Contains Allergens": "Boolean"
  },
  "OutputCols": {
    "Cuisine Type": "String",
    "Meal Type": "String",
    "Dietary Preference": "String",
    "Protein Rich": "Boolean",
    "Pregnancy Safe": "Boolean",
    "Diabetic Friendly": "Boolean"
  }
}

Ensure strict adherence to the specified JSON format for output. The `"InputCols"` section must accurately reflect the detailed input features of the dish, including ingredients, nutritional information, and other specified attributes. The `"OutputCols"` should precisely classify the dish's cuisine type, meal type, dietary preference, and health considerations based on the input provided. Each field in the output JSON must match the expected data types and structure, with boolean values for health considerations, integer values for nutritional content and spice level, and string values for all other categories. Accuracy in this structure is crucial for the utility and integrity of the generated dataset.

"""

        rspnse = client.chat.completions.create(model=model, response_format={"type": "json_object"},messages=[{'role':'system','content':prmpt},{'role': "user", 'content':"Based on the instructions, Provide output for Dish:\n"+document}])
        gpt_ans = rspnse.choices[0].message.content
        return gpt_ans

    except:
        print('TimeoutError')
        return 'openai-timeout'

# %%
response=run_GPT4("idli")

# %%
res=json.loads(response)

print(json.dumps(res,indent=4))
# Out:
# {
#     "InputCols": {
#         "List of Main Ingredients": "Rice, Lentils",
#         "Nutritional Value per Serving": {
#             "Calories": 60,
#             "Saturated Fat in daily %": 1,
#             "Sugar in g": 1,
#             "Protein in g": 2,
#             "Glycemic Index": 42
#         },
#         "Region where Dish is Popular": "South India",
#         "Description": "Idli is a traditional South Indian steamed rice and lentil cake. It is light, fluffy, and served as a healthy breakfast or snack. Idli is often accompanied by coconut chutney and sambar, making it a popular and nutritious dish in South Indian cuisine.",
#         "Spice Level": 2,
#         "Cooking Method": "Steaming",
#         "Preparation Time": 240,
#         "Contains Allergens": false
#     },
#     "OutputCols": {
#         "Cuisine Type": "South Indian",
#         "Meal Type": "Breakfast, Snack",
#         "Dietary Preference": "Veg",
#         "Protein Rich": false,
#         "Pregnancy Safe": true,
#         "Diabetic Friendly": true
#     }
# }

# %%
dishes=set([
    "Butter Chicken",
    "Paneer Tikka Masala",
    "Chole Bhature",
    "Masala Dosa",
    "Hyderabadi Biryani",
    "Rogan Josh",
    "Palak Paneer",
    "Pav Bhaji",
    "Chicken 65",
    "Dal Makhani",
    "Margherita Pizza",
    "Spaghetti Carbonara",
    "Sushi Rolls",
    "Beef Burger",
    "Caesar Salad",
    "Pad Thai",
    "Ramen Noodles",
    "Falafel Wrap",
    "Tacos al Pastor",
    "Moussaka",
    "Lamb Gyro",
    "Fish and Chips",
    "Peking Duck",
    "Kimchi Fried Rice",
    "Pho",
    "Ratatouille",
    "Quinoa Salad",
    "Veggie Burger",
    "Tom Yum Soup",
    "Empanadas",
    "Jambalaya",
    "Ceviche",
    "Bibimbap",
    "Fettuccine Alfredo",
    "Laksa",
    "Beef Stroganoff",
    "Chicken Parmesan",
    "Duck Confit",
    "Eggplant Parmigiana",
    "French Onion Soup",
    "Goulash",
    "Hummus",
    "Irish Stew",
    "Jerk Chicken",
    "Kale Salad",
    "Lasagna",
    "Meatloaf",
    "Nachos",
    "Oysters Rockefeller",
    "Paella",
    "Quiche Lorraine",
    "Shakshuka",
    "Tiramisu",
    "Udon",
    "Veal Marsala",
    "Waldorf Salad",
    "Xiao Long Bao",
    "Yakitori",
    "Zucchini Noodles",
    "Aloo Gobi",
    "Bhel Puri",
    "Cucumber Raita",
    "Dum Aloo",
    "Egg Curry",
    "Fish Curry",
    "Goan Prawn Curry",
    "Hara Bhara Kabab",
    "Idli Sambar",
    "Jalebi",
    "Kadai Paneer",
    "Lamb Vindaloo",
    "Mutton Biryani",
    "Naan",
    "Onion Bhaji",
    "Paneer Butter Masala",
    "Quinoa Biryani",
    "Ras Malai",
    "Saag Aloo",
    "Tandoori Chicken",
    "Uttapam",
    "Vegetable Jalfrezi",
    "Wheat Parotta",
    "Xacuti",
    "Yellow Dal Tadka",
    "Zarda Rice",
    "Apple Pie",
    "Banana Split",
    "Caramel Sundae",
    "Donut",
    "Eclair",
    "French Toast",
    "Gelato",
    "Hot Chocolate",
    "Ice Cream Cake",
    "Jam Tart",
    "Key Lime Pie",
    "Lemon Meringue Pie",
    "Mango Sticky Rice",
    "Nougat",
    "Olive Oil Cake",
    "Pumpkin Pie",
    "Quiche",
    "Red Velvet Cake",
    "Strawberry Cheesecake",
    "Tres Leches Cake",
    "Upside-Down Cake",
    "Vanilla Custard",
    "Waffle",
    "Xmas Cookies",
    "Yogurt Parfait",
    "Zabaglione",
        "Kachori",
        "Samosa",
        "Pani Puri",
        "Dahi Vada",
        "Pakora",
        "Bhindi Masala",
        "Gajar Ka Halwa",
        "Gulab Jamun",
        "Kulfi",
        "Rasmalai",
        "Shahi Paneer",
        "Malai Kofta",
        "Rajma",
        "Kadhi Pakora",
        "Aloo Paratha",
        "Methi Thepla",
        "Puran Poli",
        "Bisi Bele Bath",
        "Vada Pav",
        "Misal Pav",
        "Kathi Roll",
        "Chicken Chettinad",
        "Mutton Rogan Josh",
        "Fish Moilee",
        "Prawn Malai Curry",
        "Sarson Da Saag",
        "Makki Di Roti",
        "Amritsari Fish",
        "Chana Masala",
        "Paneer Bhurji",
        "Egg Bhurji",
        "Chicken Kolhapuri",
        "Mutton Keema",
        "Butter Naan",
        "Garlic Naan",
        "Lacha Paratha",
        "Tandoori Roti",
        "Bombay Duck Fry",
        "Chicken Cafreal",
        "Goan Beef Vindaloo",
        "Hyderabadi Marag",
        "Kashmiri Pulao",
        "Keema Pav",
        "Kolhapuri Vegetables",
        "Laal Maas",
        "Malabar Fish Curry",
        "Masoor Dal",
        "Moong Dal Halwa",
        "Nihari",
        "Oondhiyo",
        "Panch Phoron Tarkari",
        "Paneer Pasanda",
        "Patra Ni Machhi",
        "Phirni",
        "Pindi Chana",
        "Rabdi",
        "Samosa Chaat",
        "Sev Puri",
        "Tandoori Chicken Wings",
        "Undhiyu",
        "Veg Kolhapuri",
        "Yakhni Pulao",
        "Zunka Bhakri",
        "Achari Chicken",
        "Balti Chicken",
        "Chicken Do Pyaza",
        "Dal Tadka",
        "Egg Masala",
        "Frankie",
        "Gobi Manchurian",
        "Hakka Noodles",
        "Idiyappam",
        "Jhinga Masala",
        "Kaleji Fry",
        "Lemon Rice",
        "Masala Papad",
        "Nariyal Chutney",
        "Omelette Curry",
        "Papdi Chaat",
        "Qeema Matar",
        "Rava Idli",
        "Sindhi Curry",
        "Tawa Pulao",
        "Uppittu",
        "Varan Bhaat",
        "Chicken Xacuti",
        "Yoğurtlu Kebab",
        "Zafrani Pulao",
        "Aloo Mutter",
        "Baingan Bharta",
        "Chicken 69",
        "Dal Fry",
        "Egg Korma",
        "Fig Barfi",
        "Ghugni Chaat",
        "Handi Biryani",
        "Imarti",
        "Jalfrezi",
        "Korma",
        "Lamb Saag",
        "Mango Lassi",
        "Neer Dosa",
        "Okra Fries",
        "Paneer Lababdar",
        "Quail Fry",
        "Rogan Gosh",
        "Shrimp Curry",
        "Til Ki Chutney",
        "Urad Dal",
        "Vegetable Pakora",
        "Watermelon Curry",
        "Xacuti Masala",
        "Yogurt Rice",
        "Zarda Pulao",
    "Kachori",
    "Samosa",
    "Pani Puri",
    "Dahi Vada",
    "Pakora",
    "Bhindi Masala",
    "Gajar Ka Halwa",
    "Gulab Jamun",
    "Kulfi",
    "Rasmalai",
    "Shahi Paneer",
    "Malai Kofta",
    "Rajma",
    "Kadhi Pakora",
    "Aloo Paratha",
    "Methi Thepla",
    "Puran Poli",
    "Bisi Bele Bath",
    "Vada Pav",
    "Misal Pav",
    "Kathi Roll",
    "Chicken Chettinad",
    "Mutton Rogan Josh",
    "Fish Moilee",
    "Prawn Malai Curry",
    "Sarson Da Saag",
    "Makki Di Roti",
    "Amritsari Fish",
    "Chana Masala",
    "Paneer Bhurji",
    "Egg Bhurji",
    "Chicken Kolhapuri",
    "Mutton Keema",
    "Butter Naan",
    "Garlic Naan",
    "Lacha Paratha",
    "Tandoori Roti",
    "Bombay Duck Fry",
    "Chicken Cafreal",
    "Goan Beef Vindaloo",
    "Hyderabadi Marag",
    "Kashmiri Pulao",
    "Keema Pav",
    "Kolhapuri Vegetables",
    "Laal Maas",
    "Malabar Fish Curry",
    "Masoor Dal",
    "Moong Dal Halwa",
    "Nihari",
    "Oondhiyo",
    "Panch Phoron Tarkari",
    "Paneer Pasanda",
    "Patra Ni Machhi",
    "Phirni",
    "Pindi Chana",
    "Rabdi",
    "Samosa Chaat",
    "Sev Puri",
    "Tandoori Chicken Wings",
    "Undhiyu",
    "Veg Kolhapuri",
    "Yakhni Pulao",
    "Zunka Bhakri",
    "Achari Chicken",
    "Balti Chicken",
    "Chicken Do Pyaza",
    "Dal Tadka",
    "Egg Masala",
    "Frankie",
    "Gobi Manchurian",
    "Hakka Noodles",
    "Idiyappam",
    "Jhinga Masala",
    "Kaleji Fry",
    "Lemon Rice",
    "Masala Papad",
    "Nariyal Chutney",
    "Omelette Curry",
    "Papdi Chaat",
    "Qeema Matar",
    "Rava Idli",
    "Sindhi Curry",
    "Tawa Pulao",
    "Uppittu",
    "Varan Bhaat",
    "Chicken Xacuti",
    "Yoğurtlu Kebab",
    "Zafrani Pulao",
    "Aloo Mutter",
    "Baingan Bharta",
    "Chicken 69",
    "Dal Fry",
    "Egg Korma",
    "Fig Barfi",
    "Ghugni Chaat",
    "Handi Biryani",
    "Imarti",
    "Jalfrezi",
    "Korma",
    "Lamb Saag",
    "Mango Lassi",
    "Neer Dosa",
    "Okra Fries",
    "Paneer Lababdar",
    "Quail Fry",
    "Rogan Gosh",
    "Shrimp Curry",
    "Til Ki Chutney",
    "Urad Dal",
    "Vegetable Pakora",
    "Watermelon Curry",
    "Xacuti Masala",
    "Yogurt Rice",
    "Zarda Pulao",
    "Lasagna Bolognese",
    "Spaghetti alla Carbonara",
    "Fettuccine Alfredo",
    "Margherita Pizza",
    "Risotto alla Milanese",
    "Tiramisu",
    "Gelato",
    "Bruschetta",
    "Caprese Salad",
    "Osso Buco",
    "Panzanella",
    "Cannoli",
    "Pesto Pasta",
    "Ravioli",
    "Polenta",
    "Cheeseburger",
    "Fried Chicken",
    "BBQ Ribs",
    "Macaroni and Cheese",
    "Clam Chowder",
    "Jambalaya",
    "Cornbread",
    "Apple Pie",
    "Buffalo Wings",
    "Reuben Sandwich",
    "Hot Dogs",
    "Pancakes",
    "S'mores",
    "Caesar Salad",
    "Biscuits and Gravy",
    "General Tso's Chicken",
    "Peking Duck",
    "Dim Sum",
    "Kung Pao Chicken",
    "Sweet and Sour Pork",
    "Hot Pot",
    "Szechuan Beef",
    "Spring Rolls",
    "Wonton Soup",
    "Mapo Tofu",
    "Egg Fried Rice",
    "Dumplings",
    "Beef and Broccoli",
    "Moo Shu Pork",
    "Chow Mein",
    "Dan Dan Noodles",
    "Eggplant with Garlic Sauce",
    "Char Siu",
    "Baozi",
    "Zha Jiang Mian",
    "Chicken Parmigiana",
    "Spaghetti with Meatballs",
    "Prosciutto",
    "Minestrone Soup",
    "Gnocchi",
    "Calzone",
    "Affogato",
    "Carbonara Pizza",
    "Ribollita",
    "Arancini",
    "Saltimbocca",
    "Tortellini in Brodo",
    "Ossobuco alla Milanese",
    "Porchetta",
    "Sicilian Pizza",
    "Grilled Cheese Sandwich",
    "Philly Cheesesteak",
    "Texas Brisket",
    "New York Style Pizza",
    "Chicago Deep Dish Pizza",
    "Nachos",
    "Burrito",
    "Lobster Roll",
    "Pulled Pork Sandwich",
    "Baked Beans",
    "Corn on the Cob",
    "Chili Con Carne",
    "Meatloaf",
    "Pot Roast",
    "Fried Rice",
    "Chop Suey",
    "Lemon Chicken",
    "Beef Chow Fun",
    "Sesame Chicken",
    "Shrimp Lo Mein",
    "Mongolian Beef",
    "Cashew Chicken",
    "Honey Walnut Shrimp",
    "Fried Wontons",
    "Egg Foo Young",
    "Pineapple Bun",
    "Turnip Cake",
    "Steamed Fish",
    "Soy Sauce Chicken",
    "Roast Pork Bun",
    "Sticky Rice in Lotus Leaf"
  ])

# %%
len(dishes)
# Out:
# 311

# %%
def get_data(dish_list):

    try:
        for d in tqdm(dish_list,desc="processing",unit='item'):
            response=run_GPT4(d)
            if response!='openai-timeout':
                res_d=json.loads(response)
                json_obj=json.dumps(res_d,indent=2)

                filename=d+".json"
                with open(filename,"w") as f:
                    f.write(json_obj)
        print("Data about dishes stored successfully!")

    except:
        print("Unexpected error encountered")

# %%
get_data(dishes)
# Out:
# processing:   1%|          | 2/311 [00:05<13:01,  2.53s/item]
# TimeoutError
# processing:   1%|▏         | 4/311 [00:14<19:11,  3.75s/item]

# %%
dishes_2=set([
    "Dosa",
    "Idli",
    "Sambar",
    "Rasam",
    "Curd Rice",
    "Lemon Rice",
    "Tomato Rice",
    "Bisi Bele Bath",
    "Pongal",
    "Upma",
    "Chapati",
    "Parotta",
    "Vegetable Biryani",
    "Chicken Biryani",
    "Fish Curry",
    "Prawn Curry",
    "Masala Dosa",
    "Uttapam",
    "Vada",
    "Pesarattu",
    "Appam",
    "Kuzhambu",
    "Keerai Kootu",
    "Avial",
    "Cabbage Poriyal",
    "Chana Masala",
    "Potato Curry",
    "Cucumber Raita",
    "Mango Rice",
    "Palak Paneer",
    "Gobi Manchurian",
    "Chicken Curry",
    "Mutton Kuzhambu",
    "Egg Curry",
    "Lemon Sevai",
    "Chicken Chettinad",
    "Mysore Pak",
    "Pudina Chutney",
    "Coconut Chutney",
    "Tomato Chutney",
    "Onion Chutney",
    "Keerai Masiyal",
    "Kathirikai Gothsu",
    "Kothamalli Rice",
    "Capsicum Masala",
    "Thayir Vadai",
    "Paniyaram",
    "Murukku",
    "Badam Payasam",
    "Kesar Halwa",
    "Jackfruit Biryani",
    "Rava Kesari",
    "Chicken 65",
    "Vendakkai Puli Kuzhambu",
    "Tomato Pachadi",
    "Nei Appam",
    "Semiya Upma",
    "Mushroom Curry",
    "Rasgulla",
    "Kollu Rasam",
    "Kalaadi",
    "Kanchipuram Idli",
    "Kozhukattai",
    "Drumstick Sambar",
    "Tomato Rasam",
    "Ven Pongal",
    "Keema Biryani",
    "Palak Dal",
    "Mutton Biriyani",
    "Cabbage Kootu",
    "Kara Kuzhambu",
    "Kovakkai Poriyal",
    "Meen Kuzhambu",
    "Elaneer Payasam",
    "Aloo Gobi",
    "Cauliflower Rice",
    "Andhra Chicken Curry",
    "Nellikai Thokku",
    "Milagu Rasam",
    "Poornam Boorelu",
    "Akki Roti",
    "Mango Pachadi",
    "Chettinad Chicken Curry",
    "Kuthiraivali Pongal",
    "Kuska Biryani",
    "Mango Pickle",
    "Kongunadu Chicken Curry",
    "Kathirikai Pitlai",
    "Keerai Vadai",
    "Arachuvitta Sambar",
    "Inji Puli",
    "Kaju Katli",
    "Kollu Podi",
    "Kadai Paneer",
    "Parangikai Kootu",
    "Kavuni Arisi Payasam",
    "Udupi Sambar",
    "Keerai Thandu Kootu",
    "Kozhukattai Sundal",
    "Banana Halwa"
])

all_dishes=dishes | dishes_2

with open("dishnames.txt",'w') as f:
    for i in all_dishes:
        f.write(i+"\n")

# %%
pip install tqdm

# %%
get_data(dishes_2)

# %%
a=[]
directory_path = '/Users/anu/Documents/NLP_Project_Food/FoodData/'
for filename in os.listdir(directory_path):
    name , file_extension = os.path.splitext(filename)
    
    if file_extension.lower()=='.json' and os.path.isfile(os.path.join(directory_path, filename)):
        a.append(name)

# %%
len(a)
# Out:
# 409

# %%
#create dataframe with cols:
#Dishname (str) -- word2Vec
#List of main ingredients (list) -- word2Vec
#Calories (float)  -- scaler
#sfat (float) -- scaler
#sugar (float) -- scaler
#protein (float) -- scaler
#GI (int) -- scaler
#Region (str) -- word2Vec
#100-wrd desc (str) - sent transformer
#spice-level (int) 
#cooking-method (str) - sent transformer
#prep time (int) 
#contains allergens (boolean)

##y##
#Cusine type (str) - one-hot
#Meal type (list) - one-hot multiple
#dietary preference (str) one-hot
#protein rich (bool) 
#preganancy safe (bool)
#diabetic friendly (bool)

# %% [markdown]
# #### Load dataframe

# %%
pip install pandas

# %%
import pandas as pd
df=pd.DataFrame(columns=['DishName','Ingredients','Calories','SFat','Sugar','Protein','GI','Region','Description','SpiceLevel','CookingMethod','PrepTime','HasAllergens','Cuisine','MealType','DietaryPreference','Protein-Rich','Pregnancy-Safe','Diabetic-Friendly'])
df
# Out:
# Empty DataFrame
# Columns: [DishName, Ingredients, Calories, SFat, Sugar, Protein, GI, Region, Description, SpiceLevel, CookingMethod, PrepTime, HasAllergens, Cuisine, MealType, DietaryPreference, Protein-Rich, Pregnancy-Safe, Diabetic-Friendly]
# Index: []

# %%
def process_json(filename):
    row={}
    path='FoodData/'+filename
    with open(path,'r') as f:
        dish_det=json.load(f)
        
        row['DishName']=os.path.splitext(filename)[0]
        row['Ingredients']=[i.strip() for i in dish_det['InputCols']['List of Main Ingredients'].split(",")]
        row['Calories']=dish_det['InputCols']['Nutritional Value per Serving']['Calories']
        row['SFat']=dish_det['InputCols']['Nutritional Value per Serving']['Saturated Fat in daily %']
        row['Sugar']=dish_det['InputCols']['Nutritional Value per Serving']['Sugar in g']
        row['Protein']=dish_det['InputCols']['Nutritional Value per Serving']['Protein in g']
        row['GI']=dish_det['InputCols']['Nutritional Value per Serving']['Glycemic Index']
        row['Region']=dish_det['InputCols']['Region where Dish is Popular']
        row['Description']=dish_det['InputCols']['Description']
        row['SpiceLevel']=dish_det['InputCols']['Spice Level']
        row['CookingMethod']=dish_det['InputCols']['Cooking Method']
        row['PrepTime']=dish_det['InputCols']['Preparation Time']
        row['HasAllergens']=dish_det['InputCols']['Contains Allergens']
        row['Cuisine']=dish_det['OutputCols']['Cuisine Type']
        row['MealType']=[i.strip() for i in dish_det['OutputCols']['Meal Type'].split(",")]
        row['DietaryPreference']=dish_det['OutputCols']['Dietary Preference']
        row['Protein-Rich']=dish_det['OutputCols']['Protein Rich']
        row['Pregnancy-Safe']=dish_det['OutputCols']['Pregnancy Safe']
        row['Diabetic-Friendly']=dish_det['OutputCols']['Diabetic Friendly']

    return row

# %%
#sample
process_json('Achari Chicken.json')
# Out:
# {'DishName': 'Achari Chicken',
#  'Ingredients': ['Chicken',
#   'yogurt',
#   'tomatoes',
#   'spices (fenugreek seeds',
#   'fennel seeds',
#   'mustard seeds',
#   'nigella seeds)',
#   'ginger',
#   'garlic'],
#  'Calories': 320,
#  'SFat': 12,
#  'Sugar': 3,
#  'Protein': 30,
#  'GI': 15,
#  'Region': 'North India',
#  'Description': 'Achari Chicken is a traditional North Indian dish made with marinated chicken cooked in a tangy and spicy pickle-like gravy. The combination of pickling spices gives it a unique and flavorful taste.',
#  'SpiceLevel': 8,
#  'CookingMethod': 'Stovetop cooking',
#  'PrepTime': 45,
#  'HasAllergens': False,
#  'Cuisine': 'Indian',
#  'MealType': ['Lunch', 'Dinner'],
#  'DietaryPreference': 'Non-Veg',
#  'Protein-Rich': True,
#  'Pregnancy-Safe': False,
#  'Diabetic-Friendly': False}

# %%
for dish in tqdm(a,desc='processing',unit='item'):
    df.loc[len(df)]=process_json(dish+'.json')
# Out:
# processing:   0%|          | 0/409 [00:00<?, ?item/s]
# processing: 100%|██████████| 409/409 [00:00<00:00, 917.25item/s]

# %%
df
# Out:
#                    DishName  \
# 0                Ven Pongal
# 1              Tom Yum Soup
# 2                 Inji Puli
# 3                  Pancakes
# 4    Ossobuco alla Milanese
# ..                      ...
# 404           Kara Kuzhambu
# 405     Tortellini in Brodo
# 406              Egg Masala
# 407            French Toast
# 408             Kozhukattai
#
#                                            Ingredients  Calories  SFat  Sugar  \
# 0    [Rice, Lentils, Ghee, Cumin seeds, Black peppe...       250    15    2.0
# 1    [lemongrass, galangal, kaffir lime leaves, chi...       150    10    3.0
# 2    [Tamarind, Ginger, Jaggery, Red Chili, Mustard...       120     4   10.0
# 3      [Flour, Milk, Eggs, Baking Powder, Sugar, Salt]       200    10    6.0
# 4    [Veal shanks, Onion, Carrot, Celery, White win...       640    60    5.0
# ..                                                 ...       ...   ...    ...
# 404  [Tamarind, vegetables (like brinjal, drumstick...       150     5    3.0
# 405              [Pasta, Meat, Broth, Parmesan Cheese]       250    20    2.0
# 406   [Eggs, tomatoes, onions, garlic, ginger, spices]       220    12    4.0
# 407     [Bread, Eggs, Milk, Cinnamon, Vanilla extract]       210    12    5.0
# 408                     [Rice flour, Jaggery, Coconut]       100     5   10.0
#
#      Protein  GI             Region  \
# 0        8.0  42        South India
# 1       15.0  45           Thailand
# 2        2.0  55      Kerala, India
# 3        6.0  60      North America
# 4       40.0  45       Milan, Italy
# ..       ...  ..                ...
# 404      2.0  30  Tamil Nadu, India
# 405     15.0  45              Italy
# 406     15.0  10              India
# 407      7.0  45             France
# 408      2.0  50        South India
#
#                                            Description  SpiceLevel  \
# 0    Ven Pongal is a traditional South Indian break...           3
# 1    Tom Yum Soup is a bold and aromatic Thai soup ...           8
# 2    Inji Puli is a traditional South Indian dish f...           6
# 3    Pancakes are a popular breakfast dish made fro...           2
# 4    Ossobuco alla Milanese is a traditional Italia...           3
# ..                                                 ...         ...
# 404  Kara Kuzhambu is a spicy and tangy South India...           8
# 405  Tortellini in Brodo is a classic Italian dish ...           2
# 406  Egg Masala is a flavorful Indian dish made wit...           7
# 407  French toast is a classic breakfast dish made ...           2
# 408  Kozhukattai is a traditional South Indian dump...           1
#
#              CookingMethod  PrepTime  HasAllergens       Cuisine  \
# 0    Boiling and tempering        40         False  South Indian
# 1                  Boiling        30         False          Thai
# 2                 Stovetop        30         False  South Indian
# 3                Griddling        20          True      American
# 4                 Braising       180         False       Italian
# ..                     ...       ...           ...           ...
# 404       Stovetop cooking        40         False  South Indian
# 405                Boiling        30          True       Italian
# 406               Stovetop        30         False        Indian
# 407             Pan-Frying        20          True        French
# 408               Steaming        45         False  South Indian
#
#                    MealType DietaryPreference  Protein-Rich  Pregnancy-Safe  \
# 0               [Breakfast]               Veg          True            True
# 1           [Lunch, Dinner]           Non-Veg          True            True
# 2    [Side Dish, Condiment]               Veg         False            True
# 3               [Breakfast]        Vegetarian         False            True
# 4           [Lunch, Dinner]           Non-Veg          True           False
# ..                      ...               ...           ...             ...
# 404         [Lunch, Dinner]               Veg         False            True
# 405         [Lunch, Dinner]           Non-Veg          True           False
# 406         [Lunch, Dinner]           Non-Veg          True            True
# 407             [Breakfast]           Non-Veg         False            True
# 408        [Snack, Dessert]             Vegan         False            True
#
#      Diabetic-Friendly
# 0                 True
# 1                False
# 2                False
# 3                False
# 4                False
# ..                 ...
# 404               True
# 405              False
# 406              False
# 407              False
# 408              False
#
# [409 rows x 19 columns]

# %% [markdown]
# ### EDA

# %%
df.dtypes
# Out:
# DishName              object
# Ingredients           object
# Calories               int64
# SFat                   int64
# Sugar                float64
# Protein              float64
# GI                     int64
# Region                object
# Description           object
# SpiceLevel             int64
# CookingMethod         object
# PrepTime               int64
# HasAllergens            bool
# Cuisine               object
# MealType              object
# DietaryPreference     object
# Protein-Rich            bool
# Pregnancy-Safe          bool
# Diabetic-Friendly       bool
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 409 entries, 0 to 408
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DishName           409 non-null    object
#  1   Ingredients        409 non-null    object
#  2   Calories           409 non-null    int64
#  3   SFat               409 non-null    int64
#  4   Sugar              409 non-null    float64
#  5   Protein            409 non-null    float64
#  6   GI                 409 non-null    int64
#  7   Region             409 non-null    object
#  8   Description        409 non-null    object
#  9   SpiceLevel         409 non-null    int64
#  10  CookingMethod      409 non-null    object
#  11  PrepTime           409 non-null    int64
#  12  HasAllergens       409 non-null    bool
#  13  Cuisine            409 non-null    object
#  14  MealType           409 non-null    object
#  15  DietaryPreference  409 non-null    object
#  16  Protein-Rich       409 non-null    bool
#  17  Pregnancy-Safe     409 non-null    bool
#  18  Diabetic-Friendly  409 non-null    bool
# dtypes: bool(4), float64(2), int64(5), object(8)
# memory usage: 52.7+ KB

# %%
from wordcloud import WordCloud

text = ' '.join(df['CookingMethod'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(8,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text = ' '.join(df['Region'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(8,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text=''
for i in df['Ingredients']:
    text+=' '.join(i)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(8,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text = ' '.join(df['Description'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(8,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
print(df['SpiceLevel'].value_counts())
sns.countplot(df,x='SpiceLevel',color='pink')
# Out:
# SpiceLevel
# 2    88
# 7    75
# 3    66
# 5    44
# 8    41
# 4    35
# 6    34
# 1    19
# 0     7
# Name: count, dtype: int64
# <Axes: xlabel='SpiceLevel', ylabel='count'>

# %%
plt.figure(figsize=(3,3))
df['HasAllergens'].value_counts()
sns.countplot(data=df,x='HasAllergens',color='pink')
# Out:
# <Axes: xlabel='HasAllergens', ylabel='count'>

# %%
df['Cuisine'].value_counts()
# Out:
# Cuisine
# Indian                          141
# South Indian                     66
# American                         42
# Italian                          35
# Chinese                          26
# South Asian                      19
# Dessert                           8
# Asian                             7
# French                            7
# Japanese                          5
# Mexican                           4
# Mediterranean                     4
# Chinese-American                  4
# Thai                              3
# Latin American                    3
# Italian-American                  3
# Korean                            2
# Middle Eastern                    2
# Pakistani                         2
# Indo-Chinese                      2
# Maharashtrian                     2
# British                           2
# East Asian                        1
# Multi-Cuisine                     1
# Plant-based                       1
# Beverage                          1
# Vietnamese                        1
# Punjabi                           1
# Spanish                           1
# Middle Eastern/North African      1
# Caribbean                         1
# Hungarian                         1
# Hong Kong                         1
# Parsi                             1
# Louisiana Creole                  1
# North Indian                      1
# International                     1
# Modern                            1
# Turkish                           1
# Mixed                             1
# Russian                           1
# Irish                             1
# Name: count, dtype: int64

# %%
cuisine_mapping={'South Asian': 'Asian', 'Plant-based':'Asian', 'Japanese': 'Asian', 'Hong Kong':'Asian', 'Thai': 'Asian', 'Korean': 'Asian','Pakistani': 'Asian', 'East Asian': 'Asian', 'Vegetarian': 'Asian' , 'Vietnamese': 'Asian', 'Parsi': 'Asian', 'Mexican': 'American','Mediterranean': 'Continental', 'Hungarian': 'Continental', 'Latin American': 'Continental', 'Dessert' : 'Continental', 'British' : 'Continental', 'Russian' : 'Continental', 'Middle Eastern': 'Continental' , 'Spanish' : 'Continental', 'Beverage': 'Continental' , 'Turkish': 'Continental' , 'Middle Eastern/North African': 'Continental', 'Irish': 'Continental', 'Greek': 'Continental', 'Caribbean': 'Continental', 'Louisiana Creole': 'Continental',
'Chinese-American': 'Fusion', 'French':'Continental', 'Fusion':'Continental','Italian-American': 'Fusion', 'International':'Continental','Multi-Cuisine': 'Fusion', 'Modern': 'Fusion', 'Mixed': 'Fusion' , 'Indo-Chinese' : 'Fusion', 'Maharashtrian': 'Indian' , 'North Indian': 'Indian', 'Kashmiri': 'Indian' , 'Punjabi' : 'Indian', }

# %%
df['Cuisine'].replace(cuisine_mapping,inplace=True)
df['Cuisine'].value_counts()
# Out:
# Cuisine
# Indian          145
# South Indian     66
# American         46
# Asian            43
# Continental      36
# Italian          35
# Chinese          26
# Fusion           12
# Name: count, dtype: int64

# %%
sns.countplot(x='Cuisine',data=df,color='pink')
# Out:
# <Axes: xlabel='Cuisine', ylabel='count'>

# %%
df['DietaryPreference'].value_counts()
# Out:
# DietaryPreference
# Non-Veg       206
# Veg           123
# Vegetarian     63
# Vegan          17
# Name: count, dtype: int64

# %%
df['DietaryPreference'].replace({'Vegetarian':'Veg','Vegan':'Veg'},inplace=True)
sns.countplot(df,x='DietaryPreference',color='pink')
# Out:
# <Axes: xlabel='DietaryPreference', ylabel='count'>

# %%
df['DietaryPreference'].value_counts()
# Out:
# DietaryPreference
# Non-Veg    206
# Veg        203
# Name: count, dtype: int64

# %%
df['Diabetic-Friendly'].value_counts()
# Out:
# Diabetic-Friendly
# False    290
# True     119
# Name: count, dtype: int64

# %%
df['Pregnancy-Safe'].value_counts()
# Out:
# Pregnancy-Safe
# True     256
# False    153
# Name: count, dtype: int64

# %%
df['Protein-Rich'].value_counts()
# Out:
# Protein-Rich
# True     249
# False    160
# Name: count, dtype: int64

# %%
df['DietaryPreference'].replace({'Vegetarian':'Veg'},inplace=True)

# %%
df['DietaryPreference'].unique()
# Out:
# array(['Veg', 'Non-Veg'], dtype=object)

# %%
df['NewCuisine']=df['Cuisine'].replace({'South Indian': 'Indian','American':'Continental','Asian':'Continental','Italian':'Continental','Chinese':'Continental','Fusion':'Continental'})

# %%
df['NewCuisine'].value_counts()
# Out:
# NewCuisine
# Indian         211
# Continental    198
# Name: count, dtype: int64

# %%
pip install gensim nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in /Users/anu/Library/Python/3.9/lib/python/site-packages (4.3.2)
# Requirement already satisfied: nltk in /Users/anu/Library/Python/3.9/lib/python/site-packages (3.8.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from gensim) (1.26.3)
# Requirement already satisfied: scipy>=1.7.0 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from gensim) (6.4.0)
# Requirement already satisfied: click in /Users/anu/Library/Python/3.9/lib/python/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Users/anu/Library/Python/3.9/lib/python/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/anu/Library/Python/3.9/lib/python/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/anu/Library/Python/3.9/lib/python/site-packages (from nltk) (4.66.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#create dataframe with cols:
#Dishname (str) -- word2Vec
#List of main ingredients (list) -- word2Vec
#Calories (float)  -- scaler
#sfat (float) -- scaler
#sugar (float) -- scaler
#protein (float) -- scaler
#GI (int) -- scaler
#Region (str) -- word2Vec
#100-wrd desc (str) - sent transformer
#spice-level (int) 
#cooking-method (str) - sent transformer
#prep time (int) 
#contains allergens (boolean)

##y##
#Cusine type (str) - one-hot
#Meal type (list) - one-hot multiple
#dietary preference (str) one-hot
#protein rich (bool) 
#preganancy safe (bool)
#diabetic friendly (bool)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sentence_transformers import SentenceTransformer
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
# Out:
# /Users/anu/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
YCols=['NewCuisine','DietaryPreference','Protein-Rich','Pregnancy-Safe','Diabetic-Friendly']

# %%
one_hot_cols=['NewCuisine','DietaryPreference']
df=pd.get_dummies(df,columns=one_hot_cols)

# %%
df.shape
# Out:
# (409, 22)

# %%
from sklearn.model_selection import train_test_split
import numpy as np

np.random.seed(5)
train,test=train_test_split(df,test_size=0.2)

# %%
train.shape,test.shape
# Out:
# ((327, 22), (82, 22))

# %%
train_df=pd.DataFrame(train,columns=df.columns)
test_df=pd.DataFrame(test,columns=df.columns)

# %%
train_df.shape,test_df.shape
# Out:
# ((327, 22), (82, 22))

# %%
train_df.columns
# Out:
# Index(['DishName', 'Ingredients', 'Calories', 'SFat', 'Sugar', 'Protein', 'GI',
#        'Region', 'Description', 'SpiceLevel', 'CookingMethod', 'PrepTime',
#        'HasAllergens', 'Cuisine', 'MealType', 'Protein-Rich', 'Pregnancy-Safe',
#        'Diabetic-Friendly', 'NewCuisine_Continental', 'NewCuisine_Indian',
#        'DietaryPreference_Non-Veg', 'DietaryPreference_Veg'],
#       dtype='object')

# %%
num_cols=['Calories','SFat','Sugar','Protein','GI','SpiceLevel','PrepTime']
word2vec_cols=['DishName','Ingredients','Region']
sent_trans_cols=['Description','CookingMethod']

# %%
#numeric columns
scaler = StandardScaler()
train_df[num_cols] = scaler.fit_transform(train_df[num_cols])
test_df[num_cols]=scaler.transform(test_df[num_cols])

# %%
train_df.shape,test_df.shape
# Out:
# ((327, 22), (82, 22))

# %%
train_df
# Out:
#                   DishName                                        Ingredients  \
# 406             Egg Masala   [Eggs, tomatoes, onions, garlic, ginger, spices]
# 340     Arachuvitta Sambar  [Toor dal, tamarind, mixed vegetables, sambar ...
# 115         Shrimp Lo Mein  [Shrimp, Lo Mein noodles, Bell Peppers, Carrot...
# 360  Risotto alla Milanese  [Arborio rice, saffron, onion, white wine, Par...
# 48       Mango Sticky Rice          [Sticky rice, mango, coconut milk, sugar]
# ..                     ...                                                ...
# 400            Wonton Soup  [Thin dough, ground pork, shrimp, mushrooms, g...
# 118             Zarda Rice  [Basmati rice, sugar, ghee, nuts, raisins, saf...
# 189        Reuben Sandwich  [Corned beef, Swiss cheese, sauerkraut, rye br...
# 206          Badam Payasam          [Almonds, milk, sugar, saffron, cardamom]
# 355             Bruschetta        [Bread, Tomatoes, Olive Oil, Garlic, Basil]
#
#      Calories      SFat     Sugar   Protein        GI  \
# 406 -0.421567 -0.354128 -0.463569  0.259426 -1.874251
# 340 -0.950722 -0.879468  0.121032 -0.583838  0.451796
# 115  0.561149 -0.128983  0.121032  1.313506  0.451796
# 360  0.561149  0.246260 -0.755869 -0.478430  0.784088
# 48   0.183181  0.246260  3.336336 -0.900062  0.784088
# ..        ...       ...       ...       ...       ...
# 400 -0.723941 -0.654323 -0.755869 -0.056798 -0.545081
# 118  0.561149 -0.354128  1.874834 -0.794654  0.451796
# 189  2.526582  1.597134 -0.025118  1.840546  1.116381
# 206 -0.194786  0.246260  1.874834 -0.583838 -0.545081
# 355 -0.950722 -0.879468 -0.609719 -0.900062 -0.212789
#
#                       Region  \
# 406                    India
# 340  Tamil Nadu, South India
# 115                    China
# 360             Milan, Italy
# 48                  Thailand
# ..                       ...
# 400                    China
# 118               South Asia
# 189            United States
# 206           Southern India
# 355                    Italy
#
#                                            Description  SpiceLevel  ...  \
# 406  Egg Masala is a flavorful Indian dish made wit...    1.075341  ...
# 340  Arachuvitta Sambar is a traditional South Indi...    0.636892  ...
# 115  Shrimp Lo Mein is a popular Chinese stir-fried...   -0.240008  ...
# 360  Risotto alla Milanese is a classic Italian dis...   -0.678457  ...
# 48   Mango Sticky Rice is a classic Thai dessert co...   -1.116907  ...
# ..                                                 ...         ...  ...
# 400  Wonton soup is a traditional Chinese soup cons...   -0.678457  ...
# 118  Zarda Rice is a traditional South Asian sweet ...   -1.116907  ...
# 189  The Reuben sandwich is a classic American deli...   -1.116907  ...
# 206  Badam Payasam is a traditional Indian sweet di...   -1.116907  ...
# 355  Bruschetta is a classic Italian appetizer that...   -1.116907  ...
#
#     HasAllergens       Cuisine                  MealType Protein-Rich  \
# 406        False        Indian           [Lunch, Dinner]         True
# 340        False  South Indian           [Lunch, Dinner]         True
# 115         True       Chinese           [Lunch, Dinner]         True
# 360         True       Italian           [Lunch, Dinner]        False
# 48         False         Asian                 [Dessert]        False
# ..           ...           ...                       ...          ...
# 400         True       Chinese  [Appetizer, Main Course]         True
# 118         True         Asian                 [Dessert]        False
# 189         True      American           [Lunch, Dinner]         True
# 206         True        Indian                 [Dessert]        False
# 355        False       Italian        [Appetizer, Snack]        False
#
#     Pregnancy-Safe  Diabetic-Friendly  NewCuisine_Continental  \
# 406           True              False                   False
# 340           True               True                   False
# 115          False               True                    True
# 360           True              False                    True
# 48            True              False                    True
# ..             ...                ...                     ...
# 400           True              False                    True
# 118           True              False                    True
# 189          False              False                    True
# 206           True              False                   False
# 355           True               True                    True
#
#      NewCuisine_Indian  DietaryPreference_Non-Veg  DietaryPreference_Veg
# 406               True                       True                  False
# 340               True                      False                   True
# 115              False                       True                  False
# 360              False                      False                   True
# 48               False                      False                   True
# ..                 ...                        ...                    ...
# 400              False                       True                  False
# 118              False                       True                  False
# 189              False                       True                  False
# 206               True                      False                   True
# 355              False                      False                   True
#
# [327 rows x 22 columns]

# %%
#Sentence Transformer
sent_transform_models={}
for col in sent_trans_cols:
    model=SentenceTransformer('all-mpnet-base-v2')
    sent_transform_models[col]=model
    train_df[col+'_Embeddings'] = train_df[col].apply(lambda x: model.encode(x))
    test_df[col+'_Embeddings'] = test_df[col].apply(lambda x: model.encode(x))

# %%
train_df.shape,test_df.shape
# Out:
# ((327, 24), (82, 24))

# %%
from sklearn.decomposition import PCA

# %%
import matplotlib.pyplot as plt
#apply PCA to reduce dimensions of sentence_embeddings 
embeddings = list(train_df['Description_Embeddings'])

# Apply PCA with a large number of components
pca = PCA()
pca.fit(embeddings)

# Plot the explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance_ratio = explained_variance_ratio.cumsum()

plt.plot(cumulative_variance_ratio, marker='o')
plt.title('Cumulative Explained Variance Ratio')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.grid(True)
plt.show()

# %%
#apply PCA to reduce dimensions of sentence_embeddings 


embeddings = list(train_df['CookingMethod_Embeddings'])

# Apply PCA with a large number of components
pca = PCA()
pca.fit(embeddings)

# Plot the explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance_ratio = explained_variance_ratio.cumsum()

plt.plot(cumulative_variance_ratio, marker='o')
plt.title('Cumulative Explained Variance Ratio')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.grid(True)
plt.show()

# %%
import numpy as np

# %%
n_components={'Description':128,'CookingMethod':32}
pca_models={}
res={}
for col in sent_trans_cols:
    train_embeddings=list(train_df[col+'_Embeddings'])
    test_embeddings=list(test_df[col+'_Embeddings'])
    
    pca = PCA(n_components=n_components[col])  # Specify the desired number of components
    train_pca_result = pca.fit_transform(train_embeddings)
    pca_models[col]=pca
    test_pca_result=pca.transform(test_embeddings)
    
    # Create a DataFrame with PCA results
    cols=[col+'_PC'+str(i) for i in range(1,n_components[col]+1)]
    train_df_pca = pd.DataFrame(data=train_pca_result, columns=cols,index=train_df.index)
    test_df_pca = pd.DataFrame(data=test_pca_result, columns=cols,index=test_df.index)

    train_df=pd.concat([train_df,train_df_pca],axis=1)
    test_df=pd.concat([test_df,test_df_pca],axis=1)

# %%
train_df.shape,test_df.shape
# Out:
# ((327, 184), (82, 184))

# %%
print(train_df.columns)
# Out:
# Index(['DishName', 'Ingredients', 'Calories', 'SFat', 'Sugar', 'Protein', 'GI',
#        'Region', 'Description', 'SpiceLevel',
#        ...
#        'CookingMethod_PC23', 'CookingMethod_PC24', 'CookingMethod_PC25',
#        'CookingMethod_PC26', 'CookingMethod_PC27', 'CookingMethod_PC28',
#        'CookingMethod_PC29', 'CookingMethod_PC30', 'CookingMethod_PC31',
#        'CookingMethod_PC32'],
#       dtype='object', length=184)

# %%
train_df
# Out:
#                   DishName                                        Ingredients  \
# 406             Egg Masala   [Eggs, tomatoes, onions, garlic, ginger, spices]
# 340     Arachuvitta Sambar  [Toor dal, tamarind, mixed vegetables, sambar ...
# 115         Shrimp Lo Mein  [Shrimp, Lo Mein noodles, Bell Peppers, Carrot...
# 360  Risotto alla Milanese  [Arborio rice, saffron, onion, white wine, Par...
# 48       Mango Sticky Rice          [Sticky rice, mango, coconut milk, sugar]
# ..                     ...                                                ...
# 400            Wonton Soup  [Thin dough, ground pork, shrimp, mushrooms, g...
# 118             Zarda Rice  [Basmati rice, sugar, ghee, nuts, raisins, saf...
# 189        Reuben Sandwich  [Corned beef, Swiss cheese, sauerkraut, rye br...
# 206          Badam Payasam          [Almonds, milk, sugar, saffron, cardamom]
# 355             Bruschetta        [Bread, Tomatoes, Olive Oil, Garlic, Basil]
#
#      Calories      SFat     Sugar   Protein        GI  \
# 406 -0.421567 -0.354128 -0.463569  0.259426 -1.874251
# 340 -0.950722 -0.879468  0.121032 -0.583838  0.451796
# 115  0.561149 -0.128983  0.121032  1.313506  0.451796
# 360  0.561149  0.246260 -0.755869 -0.478430  0.784088
# 48   0.183181  0.246260  3.336336 -0.900062  0.784088
# ..        ...       ...       ...       ...       ...
# 400 -0.723941 -0.654323 -0.755869 -0.056798 -0.545081
# 118  0.561149 -0.354128  1.874834 -0.794654  0.451796
# 189  2.526582  1.597134 -0.025118  1.840546  1.116381
# 206 -0.194786  0.246260  1.874834 -0.583838 -0.545081
# 355 -0.950722 -0.879468 -0.609719 -0.900062 -0.212789
#
#                       Region  \
# 406                    India
# 340  Tamil Nadu, South India
# 115                    China
# 360             Milan, Italy
# 48                  Thailand
# ..                       ...
# 400                    China
# 118               South Asia
# 189            United States
# 206           Southern India
# 355                    Italy
#
#                                            Description  SpiceLevel  ...  \
# 406  Egg Masala is a flavorful Indian dish made wit...    1.075341  ...
# 340  Arachuvitta Sambar is a traditional South Indi...    0.636892  ...
# 115  Shrimp Lo Mein is a popular Chinese stir-fried...   -0.240008  ...
# 360  Risotto alla Milanese is a classic Italian dis...   -0.678457  ...
# 48   Mango Sticky Rice is a classic Thai dessert co...   -1.116907  ...
# ..                                                 ...         ...  ...
# 400  Wonton soup is a traditional Chinese soup cons...   -0.678457  ...
# 118  Zarda Rice is a traditional South Asian sweet ...   -1.116907  ...
# 189  The Reuben sandwich is a classic American deli...   -1.116907  ...
# 206  Badam Payasam is a traditional Indian sweet di...   -1.116907  ...
# 355  Bruschetta is a classic Italian appetizer that...   -1.116907  ...
#
#     CookingMethod_PC23  CookingMethod_PC24  CookingMethod_PC25  \
# 406           0.035072           -0.048429            0.010213
# 340          -0.021927           -0.015827           -0.063710
# 115           0.032363           -0.051134            0.001728
# 360           0.126728            0.069181           -0.081324
# 48           -0.028057            0.010656            0.014349
# ..                 ...                 ...                 ...
# 400           0.091747            0.066596            0.031013
# 118           0.018723           -0.035570           -0.010477
# 189           0.004584            0.000183           -0.031609
# 206           0.000888           -0.069742            0.005379
# 355           0.004584            0.000183           -0.031609
#
#     CookingMethod_PC26 CookingMethod_PC27  CookingMethod_PC28  \
# 406           0.037012           0.026854           -0.016552
# 340           0.030081           0.030034           -0.004554
# 115          -0.133390           0.020694            0.012082
# 360           0.003193           0.311750           -0.115427
# 48            0.003448           0.007758            0.014235
# ..                 ...                ...                 ...
# 400           0.065898          -0.122319           -0.135439
# 118          -0.031452           0.038300           -0.047234
# 189          -0.022020           0.010049            0.023909
# 206          -0.033619           0.014306            0.066044
# 355          -0.022020           0.010049            0.023909
#
#      CookingMethod_PC29  CookingMethod_PC30  CookingMethod_PC31  \
# 406            0.011336           -0.014041            0.012196
# 340           -0.008699           -0.013544            0.013098
# 115           -0.051840            0.009116            0.022713
# 360            0.058519           -0.042417            0.131638
# 48            -0.010671           -0.010706            0.006332
# ..                  ...                 ...                 ...
# 400           -0.053223           -0.037699            0.005713
# 118           -0.011044            0.042053           -0.037205
# 189            0.021246           -0.008335           -0.016724
# 206            0.024975            0.019105           -0.005087
# 355            0.021246           -0.008335           -0.016724
#
#      CookingMethod_PC32
# 406            0.011454
# 340           -0.002909
# 115            0.009009
# 360            0.104658
# 48            -0.008831
# ..                  ...
# 400            0.034126
# 118            0.004442
# 189            0.017131
# 206           -0.007150
# 355            0.017131
#
# [327 rows x 184 columns]

# %%
from nltk.tokenize import word_tokenize


 # Tokenization and Lowercasing
for col in ['DishName','Region']:
    train_df[col] = train_df[col].apply(lambda x: word_tokenize(x.lower()))
    test_df[col] = test_df[col].apply(lambda x: word_tokenize(x.lower()))

# %%
#word2Vec transformations

word2vec_models={}
for col in word2vec_cols:

    # Train Word2Vec model (Skip-gram model with a window size of 5)
    word2vec_model = Word2Vec(sentences=df[col], vector_size=8, window=5, min_count=1, workers=4, sg=0)
    word2vec_models[col]=word2vec_model

    # Function to generate text embeddings
    def text_to_embedding(tokens, model):
        vectors = [model.wv[word] for word in tokens if word in model.wv]
        return sum(vectors) if vectors else [0] * model.vector_size  # Return zeros if no valid tokens

    # Apply the function to create text embeddings
    train_df[col+'_Embedding'] = train_df[col].apply(lambda x: text_to_embedding(x, word2vec_model))
    test_df[col+'_Embedding'] = test_df[col].apply(lambda x: text_to_embedding(x, word2vec_model))
    
    # Flatten the text embeddings into multiple columns
    embedding_cols = [f'{col}_embed_{i+1}' for i in range(word2vec_model.vector_size)]
    train_df[embedding_cols] = pd.DataFrame(train_df[col+'_Embedding'].tolist(), index=train_df.index)
    test_df[embedding_cols] = pd.DataFrame(test_df[col+'_Embedding'].tolist(), index=test_df.index)
    
    # Drop the original 'text_embedding' column
    train_df = train_df.drop(columns=[col+'_Embedding'])
    test_df = test_df.drop(columns=[col+'_Embedding'])

# %%
train_df.shape,test_df.shape
# Out:
# ((327, 208), (82, 208))

# %%
for i in train_df.columns:
    print(i)
# Out:
# DishName
# Ingredients
# Calories
# SFat
# Sugar
# Protein
# GI
# Region
# Description
# SpiceLevel
# CookingMethod
# PrepTime
# HasAllergens
# Cuisine
# MealType
# Protein-Rich
# Pregnancy-Safe
# Diabetic-Friendly
# NewCuisine_Continental
# NewCuisine_Indian
# DietaryPreference_Non-Veg
# DietaryPreference_Veg
# Description_Embeddings
# CookingMethod_Embeddings
# Description_PC1
# Description_PC2
# Description_PC3
# Description_PC4
# Description_PC5
# Description_PC6
# Description_PC7
# Description_PC8
# Description_PC9
# Description_PC10
# Description_PC11
# Description_PC12
# Description_PC13
# Description_PC14
# Description_PC15
# Description_PC16
# Description_PC17
# Description_PC18
# Description_PC19
# Description_PC20
# Description_PC21
# Description_PC22
# Description_PC23
# Description_PC24
# Description_PC25
# Description_PC26
# Description_PC27
# Description_PC28
# Description_PC29
# Description_PC30
# Description_PC31
# Description_PC32
# Description_PC33
# Description_PC34
# Description_PC35
# Description_PC36
# Description_PC37
# Description_PC38
# Description_PC39
# Description_PC40
# Description_PC41
# Description_PC42
# Description_PC43
# Description_PC44
# Description_PC45
# Description_PC46
# Description_PC47
# Description_PC48
# Description_PC49
# Description_PC50
# Description_PC51
# Description_PC52
# Description_PC53
# Description_PC54
# Description_PC55
# Description_PC56
# Description_PC57
# Description_PC58
# Description_PC59
# Description_PC60
# Description_PC61
# Description_PC62
# Description_PC63
# Description_PC64
# Description_PC65
# Description_PC66
# Description_PC67
# Description_PC68
# Description_PC69
# Description_PC70
# Description_PC71
# Description_PC72
# Description_PC73
# Description_PC74
# Description_PC75
# Description_PC76
# Description_PC77
# Description_PC78
# Description_PC79
# Description_PC80
# Description_PC81
# Description_PC82
# Description_PC83
# Description_PC84
# Description_PC85
# Description_PC86
# Description_PC87
# Description_PC88
# Description_PC89
# Description_PC90
# Description_PC91
# Description_PC92
# Description_PC93
# Description_PC94
# Description_PC95
# Description_PC96
# Description_PC97
# Description_PC98
# Description_PC99
# Description_PC100
# Description_PC101
# Description_PC102
# Description_PC103
# Description_PC104
# Description_PC105
# Description_PC106
# Description_PC107
# Description_PC108
# Description_PC109
# Description_PC110
# Description_PC111
# Description_PC112
# Description_PC113
# Description_PC114
# Description_PC115
# Description_PC116
# Description_PC117
# Description_PC118
# Description_PC119
# Description_PC120
# Description_PC121
# Description_PC122
# Description_PC123
# Description_PC124
# Description_PC125
# Description_PC126
# Description_PC127
# Description_PC128
# CookingMethod_PC1
# CookingMethod_PC2
# CookingMethod_PC3
# CookingMethod_PC4
# CookingMethod_PC5
# CookingMethod_PC6
# CookingMethod_PC7
# CookingMethod_PC8
# CookingMethod_PC9
# CookingMethod_PC10
# CookingMethod_PC11
# CookingMethod_PC12
# CookingMethod_PC13
# CookingMethod_PC14
# CookingMethod_PC15
# CookingMethod_PC16
# CookingMethod_PC17
# CookingMethod_PC18
# CookingMethod_PC19
# CookingMethod_PC20
# CookingMethod_PC21
# CookingMethod_PC22
# CookingMethod_PC23
# CookingMethod_PC24
# CookingMethod_PC25
# CookingMethod_PC26
# CookingMethod_PC27
# CookingMethod_PC28
# CookingMethod_PC29
# CookingMethod_PC30
# CookingMethod_PC31
# CookingMethod_PC32
# DishName_embed_1
# DishName_embed_2
# DishName_embed_3
# DishName_embed_4
# DishName_embed_5
# DishName_embed_6
# DishName_embed_7
# DishName_embed_8
# Ingredients_embed_1
# Ingredients_embed_2
# Ingredients_embed_3
# Ingredients_embed_4
# Ingredients_embed_5
# Ingredients_embed_6
# Ingredients_embed_7
# Ingredients_embed_8
# Region_embed_1
# Region_embed_2
# Region_embed_3
# Region_embed_4
# Region_embed_5
# Region_embed_6
# Region_embed_7
# Region_embed_8

# %%
cols_to_drop=['Description_Embeddings','CookingMethod_Embeddings','DishName','Ingredients','Region','MealType','CookingMethod','Description']

train_df.drop(cols_to_drop,inplace=True,axis=1)
test_df.drop(cols_to_drop,inplace=True,axis=1)

# %%
train_df.shape,test_df.shape
# Out:
# ((327, 200), (82, 200))

# %%
train_df
# Out:
#      Calories      SFat     Sugar   Protein        GI  SpiceLevel  PrepTime  \
# 406 -0.421567 -0.354128 -0.463569  0.259426 -1.874251    1.075341 -0.486129
# 340 -0.950722 -0.879468  0.121032 -0.583838  0.451796    0.636892 -0.151468
# 115  0.561149 -0.128983  0.121032  1.313506  0.451796   -0.240008 -0.486129
# 360  0.561149  0.246260 -0.755869 -0.478430  0.784088   -0.678457 -0.263022
# 48   0.183181  0.246260  3.336336 -0.900062  0.784088   -1.116907 -0.151468
# ..        ...       ...       ...       ...       ...         ...       ...
# 400 -0.723941 -0.654323 -0.755869 -0.056798 -0.545081   -0.678457 -0.151468
# 118  0.561149 -0.354128  1.874834 -0.794654  0.451796   -1.116907  0.183194
# 189  2.526582  1.597134 -0.025118  1.840546  1.116381   -1.116907 -0.709237
# 206 -0.194786  0.246260  1.874834 -0.583838 -0.545081   -1.116907 -0.151468
# 355 -0.950722 -0.879468 -0.609719 -0.900062 -0.212789   -1.116907 -0.820791
#
#      HasAllergens       Cuisine  Protein-Rich  ...  Ingredients_embed_7  \
# 406         False        Indian          True  ...             0.191020
# 340         False  South Indian          True  ...             0.052782
# 115          True       Chinese          True  ...             0.261964
# 360          True       Italian         False  ...            -0.008047
# 48          False         Asian         False  ...             0.122017
# ..            ...           ...           ...  ...                  ...
# 400          True       Chinese          True  ...             0.073280
# 118          True         Asian         False  ...             0.167211
# 189          True      American          True  ...             0.036047
# 206          True        Indian         False  ...             0.201999
# 355         False       Italian         False  ...            -0.140168
#
#      Ingredients_embed_8  Region_embed_1  Region_embed_2  Region_embed_3  \
# 406            -0.278659        0.000000         0.00000        0.000000
# 340            -0.091707       -0.305495        -0.32404        0.342521
# 115            -0.009338        0.000000         0.00000        0.000000
# 360            -0.194479       -0.305495        -0.32404        0.342521
# 48              0.303381        0.000000         0.00000        0.000000
# ..                   ...             ...             ...             ...
# 400            -0.148132        0.000000         0.00000        0.000000
# 118            -0.088729        0.000000         0.00000        0.000000
# 189             0.027437        0.000000         0.00000        0.000000
# 206             0.188286        0.000000         0.00000        0.000000
# 355             0.188475        0.000000         0.00000        0.000000
#
#      Region_embed_4  Region_embed_5  Region_embed_6  Region_embed_7  \
# 406        0.000000        0.000000        0.000000        0.000000
# 340        1.300184       -0.019251        0.472099        0.557971
# 115        0.000000        0.000000        0.000000        0.000000
# 360        1.300184       -0.019251        0.472099        0.557971
# 48         0.000000        0.000000        0.000000        0.000000
# ..              ...             ...             ...             ...
# 400        0.000000        0.000000        0.000000        0.000000
# 118        0.000000        0.000000        0.000000        0.000000
# 189        0.000000        0.000000        0.000000        0.000000
# 206        0.000000        0.000000        0.000000        0.000000
# 355        0.000000        0.000000        0.000000        0.000000
#
#      Region_embed_8
# 406        0.000000
# 340       -0.293149
# 115        0.000000
# 360       -0.293149
# 48         0.000000
# ..              ...
# 400        0.000000
# 118        0.000000
# 189        0.000000
# 206        0.000000
# 355        0.000000
#
# [327 rows x 200 columns]

# %%
test_df
# Out:
#      Calories      SFat     Sugar   Protein        GI  SpiceLevel  PrepTime  \
# 62   0.334369 -0.504225  0.267182  1.313506  0.451796    1.513791 -0.486129
# 155  0.561149  1.371989 -0.317418  1.313506 -2.538836    0.198442  9.553724
# 316 -0.194786 -0.354128 -0.755869 -0.689246  0.451796    0.198442 -0.263022
# 290 -0.950722 -1.029565 -0.755869 -0.583838 -0.545081   -0.240008 -0.263022
# 237  0.561149  1.371989 -0.755869  0.259426  0.451796   -0.678457 -0.486129
# ..        ...       ...       ...       ...       ...         ...       ...
# 248  0.561149  0.246260  1.144083 -0.794654  1.116381   -1.116907  0.852518
# 262 -0.875128 -1.104614 -0.902019 -0.478430 -1.076749    0.198442 -0.486129
# 55  -1.177503 -0.654323 -0.317418 -1.005470 -1.541959    0.198442 -0.709237
# 336 -0.194786 -0.729371 -0.317418 -0.689246  0.784088    0.198442 -0.597683
# 353 -1.706658 -1.104614 -0.755869 -1.110878 -1.541959   -0.678457 -0.820791
#
#      HasAllergens       Cuisine  Protein-Rich  ...  Ingredients_embed_7  \
# 62          False        Indian          True  ...             0.026392
# 155         False      American          True  ...            -0.361947
# 316         False        Indian         False  ...            -0.139610
# 290          True  South Indian          True  ...             0.289236
# 237          True       Italian          True  ...             0.017986
# ..            ...           ...           ...  ...                  ...
# 248          True         Asian         False  ...             0.007013
# 262         False  South Indian          True  ...             0.062424
# 55          False  South Indian         False  ...            -0.066076
# 336         False  South Indian         False  ...            -0.154075
# 353         False        Fusion         False  ...            -0.070556
#
#      Ingredients_embed_8  Region_embed_1  Region_embed_2  Region_embed_3  \
# 62              0.227038        0.000000         0.00000        0.000000
# 155             0.092216       -0.305495        -0.32404        0.342521
# 316            -0.245401        0.000000         0.00000        0.000000
# 290            -0.350824        0.000000         0.00000        0.000000
# 237            -0.245390        0.000000         0.00000        0.000000
# ..                   ...             ...             ...             ...
# 248            -0.250062        0.000000         0.00000        0.000000
# 262            -0.151003       -0.305495        -0.32404        0.342521
# 55              0.078823        0.000000         0.00000        0.000000
# 336            -0.178661        0.000000         0.00000        0.000000
# 353             0.062010        0.000000         0.00000        0.000000
#
#      Region_embed_4  Region_embed_5  Region_embed_6  Region_embed_7  \
# 62         0.000000        0.000000        0.000000        0.000000
# 155        1.300184       -0.019251        0.472099        0.557971
# 316        0.000000        0.000000        0.000000        0.000000
# 290        0.000000        0.000000        0.000000        0.000000
# 237        0.000000        0.000000        0.000000        0.000000
# ..              ...             ...             ...             ...
# 248        0.000000        0.000000        0.000000        0.000000
# 262        1.300184       -0.019251        0.472099        0.557971
# 55         0.000000        0.000000        0.000000        0.000000
# 336        0.000000        0.000000        0.000000        0.000000
# 353        0.000000        0.000000        0.000000        0.000000
#
#      Region_embed_8
# 62         0.000000
# 155       -0.293149
# 316        0.000000
# 290        0.000000
# 237        0.000000
# ..              ...
# 248        0.000000
# 262       -0.293149
# 55         0.000000
# 336        0.000000
# 353        0.000000
#
# [82 rows x 200 columns]

# %%
train_df.isna().sum().sum(),test_df.isna().sum().sum()
# Out:
# (0, 0)

# %%
train_df.drop(['Cuisine'],axis=1,inplace=True)
test_df.drop('Cuisine',axis=1,inplace=True)

# %%
#create dataframe with cols:
#Dishname (str) -- word2Vec
#List of main ingredients (list) -- word2Vec
#Calories (float)  -- scaler
#sfat (float) -- scaler
#sugar (float) -- scaler
#protein (float) -- scaler
#GI (int) -- scaler
#Region (str) -- word2Vec
#100-wrd desc (str) - sent transformer
#spice-level (int) 
#cooking-method (str) - sent transformer
#prep time (int) 
#contains allergens (boolean)

##y##
#Cusine type (str) - one-hot
#dietary preference (str) one-hot
#protein rich (bool) 
#preganancy safe (bool)
#diabetic friendly (bool)

# %%
y_cols=['Protein-Rich','Pregnancy-Safe','Diabetic-Friendly']

for i in train_df.columns:
    if i[:len('NewCuisine')]=='NewCuisine':
        y_cols.append(i)

    if i[:len("DietaryPreference")]=='DietaryPreference':
        y_cols.append(i)

x_cols=[i for i in train_df.columns if i not in y_cols]

# %%
len(x_cols),len(y_cols)
# Out:
# (192, 7)

# %%
x_train,y_train=train_df[x_cols],train_df[y_cols]
x_test,y_test=test_df[x_cols],test_df[y_cols]

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((327, 192), (327, 7), (82, 192), (82, 7))

# %%
for i in x_train.columns:
    if x_train[i].dtype=='bool':
        x_train[i]=x_train[i].astype('int')
        x_test[i]=x_test[i].astype('int')    
for i in y_train.columns:
    if y_train[i].dtype=='bool':
        y_train[i]=y_train[i].astype('int')
        y_test[i]=y_test[i].astype('int')
# Out:
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train[i]=x_train[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test[i]=x_test[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train[i]=y_train[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test[i]=y_test[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train[i]=y_train[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test[i]=y_test[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train[i]=y_train[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test[i]=y_test[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train[i]=y_train[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test[i]=y_test[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train[i]=y_train[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test[i]=y_test[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train[i]=y_train[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test[i]=y_test[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train[i]=y_train[i].astype('int')
# /var/folders/2p/d_5l4xlj7ygbv8ldw505sjnr0000gn/T/ipykernel_10649/2801834269.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test[i]=y_test[i].astype('int')

# %% [markdown]
# ### Text classification Model building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.multioutput import MultiOutputClassifier
from sklearn.preprocessing import MultiLabelBinarizer

# %%
pip install xgboost
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in /Users/anu/Library/Python/3.9/lib/python/site-packages (2.0.3)
# Requirement already satisfied: numpy in /Users/anu/Library/Python/3.9/lib/python/site-packages (from xgboost) (1.26.3)
# Requirement already satisfied: scipy in /Users/anu/Library/Python/3.9/lib/python/site-packages (from xgboost) (1.11.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Initialize models
models = {
    'Logistic Regression': MultiOutputClassifier(LogisticRegression()),
    'SVC': MultiOutputClassifier(SVC()),
    'Random Forest': MultiOutputClassifier(RandomForestClassifier()),
    'XGBoost': MultiOutputClassifier(XGBClassifier())
    }

# Train and evaluate each model
for name, model in models.items():
    print(f"\n{name}:\n")

    model.fit(x_train, y_train)

    y_pred = model.predict(x_test)

    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)

    print(f"{name} Accuracy: {accuracy:.4f}")
# Out:
# Logistic Regression:
#
# Logistic Regression Accuracy: 0.5854
#
# SVC:
#
# SVC Accuracy: 0.5732
#
# Random Forest:
#
# Random Forest Accuracy: 0.5000
#
# XGBoost:
#
# XGBoost Accuracy: 0.5732

# %% [markdown]
# ### 1. Protein-Rich

# %%
protein_models= {
    'Logistic Regression': LogisticRegression(),
    'SVC': SVC(),
    'Random Forest': RandomForestClassifier(),
    'XGBoost': XGBClassifier()
    }

# %%
for i in protein_models:
    print(i,"\n")
    y_train_protein=y_train['Protein-Rich']
    y_test_protein=y_test['Protein-Rich']

    model=protein_models[i]
    model.fit(x_train,y_train_protein)
    ypred_protein=model.predict(x_test)

    print("Accuracy: ",100*accuracy_score(y_test_protein,ypred_protein))
    print(classification_report(y_test_protein,ypred_protein))
# Out:
# Logistic Regression
#
# Accuracy:  90.2439024390244
#               precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89        38
#            1       0.88      0.95      0.91        44
#
#     accuracy                           0.90        82
#    macro avg       0.91      0.90      0.90        82
# weighted avg       0.91      0.90      0.90        82
#
# SVC
#
# Accuracy:  89.02439024390245
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.88        38
#            1       0.87      0.93      0.90        44
#
#     accuracy                           0.89        82
#    macro avg       0.89      0.89      0.89        82
# weighted avg       0.89      0.89      0.89        82
#
# Random Forest
#
# Accuracy:  89.02439024390245
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.88        38
#            1       0.87      0.93      0.90        44
#
#     accuracy                           0.89        82
#    macro avg       0.89      0.89      0.89        82
# weighted avg       0.89      0.89      0.89        82
#
# XGBoost
#
# Accuracy:  92.6829268292683
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92        38
#            1       0.91      0.95      0.93        44
#
#     accuracy                           0.93        82
#    macro avg       0.93      0.92      0.93        82
# weighted avg       0.93      0.93      0.93        82

# %% [markdown]
# XGBoost perfroms better for protein-rich tag

# %% [markdown]
# ### 2. Diabetic-Friendly

# %%
diabetic_models= {
    'Logistic Regression': LogisticRegression(),
    'SVC': SVC(),
    'Random Forest': RandomForestClassifier(),
    'XGBoost': XGBClassifier()
    }

# %%
for i in diabetic_models:
    print(i,"\n")
    y_train_diabetic=y_train['Diabetic-Friendly']
    y_test_diabetic=y_test['Diabetic-Friendly']

    model=diabetic_models[i]
    model.fit(x_train,y_train_diabetic)
    ypred_protein=model.predict(x_test)

    print("Accuracy: ",100*accuracy_score(y_test_diabetic,ypred_protein))
    print(classification_report(y_test_protein,ypred_protein))
# Out:
# Logistic Regression
#
# Accuracy:  85.36585365853658
#               precision    recall  f1-score   support
#
#            0       0.40      0.61      0.48        38
#            1       0.38      0.20      0.26        44
#
#     accuracy                           0.39        82
#    macro avg       0.39      0.40      0.37        82
# weighted avg       0.38      0.39      0.36        82
#
# SVC
#
# Accuracy:  86.58536585365853
#               precision    recall  f1-score   support
#
#            0       0.39      0.61      0.47        38
#            1       0.35      0.18      0.24        44
#
#     accuracy                           0.38        82
#    macro avg       0.37      0.39      0.36        82
# weighted avg       0.37      0.38      0.35        82
#
# Random Forest
#
# Accuracy:  86.58536585365853
#               precision    recall  f1-score   support
#
#            0       0.38      0.63      0.48        38
#            1       0.26      0.11      0.16        44
#
#     accuracy                           0.35        82
#    macro avg       0.32      0.37      0.32        82
# weighted avg       0.32      0.35      0.31        82
#
# XGBoost
#
# Accuracy:  90.2439024390244
#               precision    recall  f1-score   support
#
#            0       0.40      0.63      0.49        38
#            1       0.36      0.18      0.24        44
#
#     accuracy                           0.39        82
#    macro avg       0.38      0.41      0.37        82
# weighted avg       0.38      0.39      0.36        82

# %% [markdown]
# XGBoost performs better for Diabetic-Friendly tag

# %% [markdown]
# ### 3. Pregnancy-Safe

# %%
pregnancy_models= {
    'Logistic Regression': LogisticRegression(),
    'SVC': SVC(),
    'Random Forest': RandomForestClassifier(),
    'XGBoost': XGBClassifier()
    }

# %%
for i in pregnancy_models:
    print(i,"\n")
    y_train_preg=y_train['Pregnancy-Safe']
    y_test_preg=y_test['Pregnancy-Safe']

    model=pregnancy_models[i]
    model.fit(x_train,y_train_preg)
    ypred_preg=model.predict(x_test)

    print("Accuracy: ",100*accuracy_score(y_test_preg,ypred_preg))
    print(classification_report(y_test_preg,ypred_preg))
# Out:
# Logistic Regression
#
# Accuracy:  89.02439024390245
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83        27
#            1       0.91      0.93      0.92        55
#
#     accuracy                           0.89        82
#    macro avg       0.88      0.87      0.87        82
# weighted avg       0.89      0.89      0.89        82
#
# SVC
#
# Accuracy:  87.8048780487805
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        27
#            1       0.91      0.91      0.91        55
#
#     accuracy                           0.88        82
#    macro avg       0.86      0.86      0.86        82
# weighted avg       0.88      0.88      0.88        82
#
# Random Forest
#
# Accuracy:  85.36585365853658
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.75        27
#            1       0.85      0.95      0.90        55
#
#     accuracy                           0.85        82
#    macro avg       0.85      0.81      0.82        82
# weighted avg       0.85      0.85      0.85        82
#
# XGBoost
#
# Accuracy:  84.14634146341463
#               precision    recall  f1-score   support
#
#            0       0.79      0.70      0.75        27
#            1       0.86      0.91      0.88        55
#
#     accuracy                           0.84        82
#    macro avg       0.83      0.81      0.82        82
# weighted avg       0.84      0.84      0.84        82

# %% [markdown]
# Logistic Regression performs better for Pregnancy-Safe tag

# %% [markdown]
# ### 4. DietaryPreference

# %%
dietary_models = {
    'Logistic Regression': MultiOutputClassifier(LogisticRegression()),
    'SVC': MultiOutputClassifier(SVC()),
    'Random Forest': MultiOutputClassifier(RandomForestClassifier()),
    'XGBoost': MultiOutputClassifier(XGBClassifier())
    }

# %%
dietary_cols=['DietaryPreference_Veg','DietaryPreference_Non-Veg']

for i in dietary_models:
    print(i,"\n")

    y_train_diet=y_train[dietary_cols]
    y_test_diet=y_test[dietary_cols]

    model=dietary_models[i]
    model.fit(x_train,y_train_diet)
    ypred_diet=model.predict(x_test)

    print("Accuracy: ",100*accuracy_score(y_test_diet,ypred_diet))
    print(classification_report(y_test_diet,ypred_diet))
# Out:
# Logistic Regression
#
# Accuracy:  86.58536585365853
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87        43
#            1       0.87      0.85      0.86        39
#
#    micro avg       0.87      0.87      0.87        82
#    macro avg       0.87      0.86      0.87        82
# weighted avg       0.87      0.87      0.87        82
#  samples avg       0.87      0.87      0.87        82
#
# SVC
#
# Accuracy:  85.36585365853658
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86        43
#            1       0.86      0.82      0.84        39
#
#    micro avg       0.85      0.85      0.85        82
#    macro avg       0.85      0.85      0.85        82
# weighted avg       0.85      0.85      0.85        82
#  samples avg       0.85      0.85      0.85        82
#
# Random Forest
#
# Accuracy:  80.48780487804879
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85        43
#            1       0.79      0.87      0.83        39
#
#    micro avg       0.84      0.84      0.84        82
#    macro avg       0.84      0.84      0.84        82
# weighted avg       0.85      0.84      0.84        82
#  samples avg       0.82      0.84      0.83        82
#
# XGBoost
# /Users/anu/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy:  90.2439024390244
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90        43
#            1       0.88      0.92      0.90        39
#
#    micro avg       0.90      0.90      0.90        82
#    macro avg       0.90      0.90      0.90        82
# weighted avg       0.90      0.90      0.90        82
#  samples avg       0.90      0.90      0.90        82

# %% [markdown]
# XGBoost works better for dietary-preference tag

# %% [markdown]
# ### 5. Cuisine

# %%
cuisine_models = {
    'Logistic Regression': MultiOutputClassifier(LogisticRegression()),
    'SVC': MultiOutputClassifier(SVC()),
    'Random Forest': MultiOutputClassifier(RandomForestClassifier()),
    'XGBoost': MultiOutputClassifier(XGBClassifier())
    }

# %%
cuisine_cols=[]
for i in y_train.columns:
    if i[:len('NewCuisine')]=='NewCuisine':
        cuisine_cols.append(i)

for i in cuisine_models:
    print(i,"\n")
    y_train_cuisine=y_train[cuisine_cols]
    y_test_cuisine=y_test[cuisine_cols]

    model=cuisine_models[i]
    model.fit(x_train,y_train_cuisine)
    ypred_cuisine=model.predict(x_test)

    print("Accuracy:",100*accuracy_score(y_test_cuisine,ypred_cuisine))
    print(classification_report(y_test_cuisine,ypred_cuisine))
# Out:
# Logistic Regression
#
# Accuracy: 93.90243902439023
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94        42
#            1       0.89      1.00      0.94        40
#
#    micro avg       0.94      0.94      0.94        82
#    macro avg       0.94      0.94      0.94        82
# weighted avg       0.95      0.94      0.94        82
#  samples avg       0.94      0.94      0.94        82
#
# SVC
#
# Accuracy: 91.46341463414635
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92        42
#            1       0.90      0.93      0.91        40
#
#    micro avg       0.91      0.91      0.91        82
#    macro avg       0.91      0.91      0.91        82
# weighted avg       0.91      0.91      0.91        82
#  samples avg       0.91      0.91      0.91        82
#
# Random Forest
#
# Accuracy: 86.58536585365853
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87        42
#            1       0.87      1.00      0.93        40
#
#    micro avg       0.90      0.90      0.90        82
#    macro avg       0.91      0.90      0.90        82
# weighted avg       0.91      0.90      0.90        82
#  samples avg       0.88      0.90      0.89        82
#
# XGBoost
# /Users/anu/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 91.46341463414635
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91        42
#            1       0.88      0.95      0.92        40
#
#    micro avg       0.91      0.91      0.91        82
#    macro avg       0.92      0.92      0.91        82
# weighted avg       0.92      0.91      0.91        82
#  samples avg       0.91      0.91      0.91        82

# %% [markdown]
# Logistic Regression performs better for Cuisine tag

# %% [markdown]
# Hence, by combining the best_performing models for each tag, we have:

# %%
best_models={
    'Protein-Rich':protein_models['XGBoost'],
    'Diabetic-Friendly':diabetic_models['XGBoost'],
    'Pregnancy-Safe':pregnancy_models['Logistic Regression'],
    'DietaryPreference':dietary_models['XGBoost'],
    'Cuisine':cuisine_models['Logistic Regression']
}

# %% [markdown]
# Saving models

# %%
import pickle

# %%
for i in best_models:
    with open(i+'.pkl','wb') as f:
        pickle.dump(best_models[i],f)

# %%
with open('Scaler.pkl','wb') as f:
    pickle.dump(scaler,f)

# %%
for col in sent_trans_cols:
    with open(col+'_sent_trans.pkl','wb') as f:
        pickle.dump(sent_transform_models[col],f)
    with open(col+'_pca.pkl','wb') as f:
        pickle.dump(pca_models[col],f)

# %%
for col in word2vec_cols:
    with open(col+'_w2v.pkl','wb') as f:
        pickle.dump(word2vec_models[col],f)

# %% [markdown]
# ## Tag Generation

# %%
#Preprocess columns
def predict_model(new_df):
    #numeric columns
    new_df[num_cols]=scaler.transform(new_df[num_cols])

    #text
    for col in sent_trans_cols:
        model=sent_transform_models[col]
        new_df[col+'_Embeddings'] = new_df[col].apply(lambda x: model.encode(x))

        new_embeddings=list(new_df[col+'_Embeddings'])
        
        pca=pca_models[col]
        new_pca_result=pca.transform(new_embeddings)
        
        # Create a DataFrame with PCA results
        cols=[col+'_PC'+str(i) for i in range(1,n_components[col]+1)]
        new_df_pca = pd.DataFrame(data=new_pca_result, columns=cols,index=new_df.index)
        new_df=pd.concat([new_df,new_df_pca],axis=1)

    for col in ['DishName','Region']:
        new_df[col] = new_df[col].apply(lambda x: word_tokenize(x.lower()))

    for col in word2vec_cols:

        word2vec_model=word2vec_models[col]
        # Function to generate text embeddings
        def text_to_embedding(tokens, model):
            vectors = [model.wv[word] for word in tokens if word in model.wv]
            return sum(vectors) if vectors else [0] * model.vector_size  # Return zeros if no valid tokens

        new_df[col+'_Embedding'] = new_df[col].apply(lambda x: text_to_embedding(x, word2vec_model))
        
        # Flatten the text embeddings into multiple columns
        embedding_cols = [f'{col}_embed_{i+1}' for i in range(word2vec_model.vector_size)]
        new_df[embedding_cols] = pd.DataFrame(new_df[col+'_Embedding'].tolist(), index=new_df.index)
        
        # Drop the original 'text_embedding' column
        new_df = new_df.drop(columns=[col+'_Embedding'],axis=1)
        

    for i in cols_to_drop:
        if i in new_df.columns:
            new_df.drop(i,inplace=True,axis=1)

    for i in new_df.columns:
        if new_df[i].dtype=='bool':
            new_df[i]=new_df[i].astype('int')
            new_df[i]=new_df[i].astype('int')    

    x_test_new=new_df[x_cols]
    ypred_protein=xgb_protein.predict(x_test_new)
    ypred_diabetic=xgb_diabetic.predict(x_test_new)
    ypred_preg=xgb_preg.predict(x_test_new)
    ypred_diet=xgb_diet.predict(x_test_new)
    ypred_meal=xgb_meal.predict(x_test_new)
    ypred_cuisine=xgb_cuisine.predict(x_test_new)

    return ypred_protein,ypred_diet,ypred_preg,ypred_diabetic,ypred_meal,ypred_cuisine

# %%
def get_tags_from_model(dish):

    #if user enters feature info predict using trained model
    ch=input("Data not avilable in database.\nWould you like to enter more details about the dish and its nutritional value? (Y/N)")
    if ch=='Y' or ch=='y':
        new_df={}
        new_df['DishName']=dish
        new_data_ing=input("Enter the main ingredients as comma separated values: ").split(",")
        new_df['Ingredients']=new_data_ing
        new_df['Calories']=int(input("Enter amount of calories per serving: "))
        new_df['Protein']=float(input("Enter amount of protein in g per serving: "))
        new_df['SFat']=float(input("Enter amount of saturated fat in g per serving: "))
        new_df['Sugar']=float(input("Enter amount of sugar in g per serving: "))
        new_df['GI']=int(input("Enter glycemic index in per serving: "))
        new_df['Region']=input("Enter where the dish is popular: ")
        new_df['Description']=input("Enter a 100-wrd description about the dish: ")
        new_df['CookingMethod']=input("Enter the cooking method of dish: ")
        new_df['HasAllergens']=int(input("Does the dish contain any allergens? (1/0)"))
        new_df['PrepTime']=int(input("Enter the approximate time taken to prepare the dish in mins: "))
        new_df['SpiceLevel']=int(input("Enter spice level of dish on a scale of 1 to 10: "))
    
        new_df=pd.DataFrame(new_df)
        ypred_protein,ypred_diet,ypred_preg,ypred_diabetic,ypred_meal,ypred_cuisine=predict_model(new_df)
              
        print("\nTags generated using model predictions:\n")
        tags=[]
        seafood=['Fish','Shrimp','Prawns','Crab','Lobster','Clams','Mussels','Oysters','Scallops','Squid']
        for i in new_data_ing:
            if i in seafood:
                tags.append('Seafood')
                break

        if 'Chicken' in new_data_ing[:2]:
            tags.append('Chicken')

        if 'Egg' in new_data_ing[:2] or 'Eggs' in new_data_ing[:2]:
            tags.append("Eggs")

        if 'Mutton' in new_data_ing[:2]:
            tags.append('Mutton')

        millets=['Jowar', 'Bajra', 'Ragi', 'Kangni', 'Kutki', 'Jhangora', 'Kodra', 'Cheena', 'Korle']
        for i in new_data_ing[:5]:
            if i in millets:
                tags.append('Millet-Based')

        if (new_df['SpiceLevel']>5).any():
            tags.append('Spicy')

        if (new_df['HasAllergens']==1).any():
            tags.append("May Contain Allergens")

        if ypred_protein[0]:
            tags.append("protein-Rich")

        if ypred_preg[0]:
            tags.append("Pregnancy-Safe")

        if ypred_diabetic[0]:
            tags.append("Diabetic-Friendly")

        #interpret dietary_preference, cuisine and mealtype results
        diet=None
        diet_cols=['DietaryPreference_Veg','DietaryPreference_Non-Veg','DietaryPreference_Vegan']

        for i in range(len(ypred_diet[0])):
            if ypred_diet[0][i]==1:
                diet=diet_cols[i].split('_')[1]
        if diet is not None:
            tags.append(diet)
            #print("Dietary preference: ",diet)

        cuisine=None
        for i in range(len(ypred_cuisine[0])):
            if ypred_cuisine[0][i]==1:
                cuisine=cuisine_cols[i].split('_')[1]
                break 
        if cuisine is not None:
            tags.append(cuisine)
            #print("Cuisine Type: ",cuisine)

        meal_type=[]
        for i in range(len(ypred_meal[0])):
            if ypred_meal[0][i]==1:
                meal_type.append(mealtype_cols[i].split('_')[1])
        if meal_type!=[]:        
            #print("Meal type:",meal_type)
            tags.append('/'.join(meal_type))
        return tags
    
    #if user doesn't want to enter details, get data from API
    else:
        print("\nFetching data using API...\n")
        return get_tags_from_API(dish)

# %%
def generate_tags(dish):

    #check if dish already exists in DB
    if dish in df['DishName'].unique():
        data=df[df['DishName']==dish]
        return get_tags_from_DB(data)
    
    else:
        print("Dish not available in database.\n")
        
        '''desc=input("Enter a short description about the dish: ")
        #check if a similar dish exists in DB
        data_idx=get_similar_dish(desc)
        data=df.iloc[data_idx]
        print("Found a similar dish in database: ",data['DishName'])
        
        if dish is not None:
            return get_tags_from_DB(data)'''
        
        return get_tags_from_model(dish)

# %%
dish=input("Enter name of dish you would like to add: ")
tags=generate_tags(dish)
print(dish," : ",tags)
# Out:
# Dish not available in database.
#
#
# Tags generated using model predictions:
#
# Brownie  :  ['Pregnancy-Safe', 'Non-Veg', 'American', 'Dessert']
